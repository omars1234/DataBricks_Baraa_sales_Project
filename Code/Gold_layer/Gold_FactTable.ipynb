# %%
# %sql
SELECT * FROM bara_slaes_project.silver.sales_info;

# %%
# %sql
SELECT 
    sal.Order_Number,
    prod.Product_srgk,
    cust.Customer_srgk,
    sal.Order_Date,
    sal.Ship_Date,
    sal.Due_Date,
    sal.Sales,
    sal.Quantity,
    sal.Price    

 FROM bara_slaes_project.silver.sales_info AS sal
 LEFT JOIN  bara_slaes_project.gold.dimproduct_info AS prod
ON sal.Product_Key = prod.Product_Key
LEFT JOIN  bara_slaes_project.gold.DimCustomer_info AS cust
ON sal.Customer_ID = cust.Customer_ID

# %%
query="""
SELECT 
    sal.Order_Number,
    prod.Product_srgk,
    cust.Customer_srgk,
    sal.Order_Date,
    sal.Ship_Date,
    sal.Due_Date,
    sal.Sales,
    sal.Quantity,
    sal.Price    

 FROM bara_slaes_project.silver.sales_info AS sal
 LEFT JOIN  bara_slaes_project.gold.dimproduct_info AS prod
ON sal.Product_Key = prod.Product_Key
LEFT JOIN  bara_slaes_project.gold.DimCustomer_info AS cust
ON sal.Customer_ID = cust.Customer_ID
"""

# %%
df = spark.sql(query)
df.write.mode("overwrite")\
    .format("delta")\
        .saveAsTable("bara_slaes_project.gold.FacTable")

# %%
# %sql
SELECT * FROM bara_slaes_project.gold.FacTable
