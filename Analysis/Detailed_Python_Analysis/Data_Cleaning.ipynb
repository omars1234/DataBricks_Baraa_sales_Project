# %%
# %run /Workspace/Users/omars.soub@gmail.com/DataBricks_Baraa_sales_Project/Analysis/Detailed_Python_Analysis/Data_Ingestion

# %%
from pyspark.sql.functions import col,year,monthname,month

# %%
def data_cleaning(df):
    df=(
        df
        .withColumn("order_year",year(col("Order_Date")))
        .withColumn("order_month",monthname(col("Order_Date")))
        .withColumn("order_month_number",month(col("Order_Date")))
        )
    df=df.select('Gender', 'marital_status', 'Country', 'Product_Line', 'Category_Name','Sub_Category_Name', 'Maintenance',"Sales")

    return df

# %%
df=data_cleaning(df)
